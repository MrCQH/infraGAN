# %%
# !git clone https://github.com/MrCQH/infraGAN.git

# %%
import os
os.chdir('/content/infraGAN/')

# %%
# !python -m pip install --index-url https://pypi.anaconda.org/intel/simple --extra-index-url https://pypi.org/simple mkl_fft
# !python -m pip install --index-url https://pypi.anaconda.org/intel/simple --extra-index-url https://pypi.org/simple mkl_random
# !python -m pip install --index-url https://pypi.anaconda.org/intel/simple --extra-index-url https://pypi.org/simple mkl_service

# %%
# !pip install -r requirements.txt

# %%
# !pip install torch torchvision
# !pip install visdom
# !pip install dominate

# %%
# 运行后出现URL，点击获得你的认证码
from google.colab import drive
drive.mount('/content/drive')

# %%
# 列出你云盘里有啥
# !ls "/content/drive//My Drive/"

# %%
# !cp -r "/content/drive//My Drive/vis2gbnir_dataset_infraGAN/" "/content/infraGAN/datasets"

# %%
# !python train.py --dataset_mode VEDAI --dataroot /content/infraGAN/datasets/precross_vis2gbnir_infragan --name infragan_vedai --model infragan --which_model_netG unet_256 --which_model_netD unetdiscriminator --which_direction AtoB --input_nc 3 --output_nc 1 --lambda_A 100  --no_lsgan --norm batch --pool_size 0 --loadSize 286 --fineSize 256 --gpu_ids 0 --nThreads 8 --batchSize 4
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#     self.connect()
#   File "/usr/local/lib/python3.8/dist-packages/urllib3/connection.py", line 181, in connect
#     conn = self._new_conn()
#   File "/usr/local/lib/python3.8/dist-packages/urllib3/connection.py", line 167, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fe5e2464d30>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/usr/local/lib/python3.8/dist-packages/urllib3/connectionpool.py", line 637, in urlopen
#     retries = retries.increment(method, url, error=e, _pool=self,
#   File "/usr/local/lib/python3.8/dist-packages/urllib3/util/retry.py", line 399, in increment
# ...
